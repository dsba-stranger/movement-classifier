# %%
import os
import sys
import numpy as np
import pandas as pd
from matplotlib import pylab as plt
import scipy.integrate
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\kirill-korolev\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['fft', 'clf', 'plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
import logging
logging.basicConfig(filename='movement_classifier.log', level=logging.DEBUG, 
                    format='%(asctime)s %(levelname)s %(name)s %(message)s')
logger = logging.getLogger(__name__)

# %%
def read_csv(file, delimeter):
    NUM_COLUMNS = 5
    try:
        df = pd.read_csv(file, delimiter=delimeter)
        if df.shape[1] == NUM_COLUMNS:    
            return df
        logger.error('%d columns are required: %s\n', NUM_COLUMNS, file)
    except Exception as exc:
        logger.error('Parsing CSV error with delimeter="%s": %s\n%s\n', delimeter, exc, file)
    return None

def read_data(directory):
    cwd = os.getcwd()
    data = []
    
    for path in sorted(os.listdir(directory)):
        full_path = os.path.join(cwd, directory, path)
        if os.path.isfile(full_path):
            df1 = read_csv(full_path, ';')
            df2 = read_csv(full_path, ',')
            df = df2 if df1 is None else df1

            if df is None:
                logger.error('Skipping corrupted dataset: %s\n', full_path)
                continue
                
            data.append((df, full_path.split('\\')[-1]))
    
    print('{:.2f}% succesfully parsed'.format(len(data) / len(os.listdir(directory)) * 100))
    return data
    
data = read_data('data/Public-data')
# Out:
# 99.74% succesfully parsed

# %%
testing_data = read_data('data/kaggle_data_open')
# Out:
# 100.00% succesfully parsed

# %%
len(data), len(testing_data)
# Out:
# (760, 183)

# %%
def rotation_matrix_from_vectors(vec1, vec2):
    a, b = (vec1 / numpy.linalg.norm(vec1)).reshape(3), (vec2 / numpy.linalg.norm(vec2)).reshape(3)
    v = numpy.cross(a, b)
    if any(v):
        c = numpy.dot(a, b)
        s = numpy.linalg.norm(v)
        mat = numpy.array([[0, -v[2], v[1]], [v[2], 0, -v[0]], [-v[1], v[0], 0]])
        return numpy.eye(3) + mat + mat.dot(mat) * ((1 - c) / (s ** 2))
    else:
        return numpy.eye(3)

# %%
def integrate(lst, dt):
    res = []
    s = 0
    for elem in lst:
        s += elem * dt
        res.append(s)
    return res

# %%
def fourier_transform(y, fs):
    n = len(y) # length of the signal
    k = np.arange(n)
    T = n/fs
    frq = k/T # two sides frequency range
    frq = frq[:len(frq)//2] # one side frequency range

    Y = np.fft.fft(y)/n # dft and normalization
    Y = Y[:n//2]
    
    yabs = abs(Y)
    
    return frq, yabs

# %%
CLASSES = {'стояние': ['тояни', 'месте', 'stay', 'око', 'tand'], 'ходьба': ['одьб', 'аг', 'отьб'], 'бег': ['ег', 'running'], 'велосипед' : ['елоси'], 'лестница' : ['естн', 'одъ', 'tair'], 
           'автомобиль' : ['втомо', 'ашин'], 'метро' : ['метро'], 'автобус' : ['автоб'], 'самокат' : ['амок']}

ANSWERS = {'стояние' : 0, 'ходьба' : 1, 'бег' : 2, 'велосипед' : 3, 'лестница' : 4, 
           'автомобиль' : 5, 'метро' : 6, 'автобус' : 7, 'самокат' : 8}

# %%
def get_type(name):
    return name.split("_")[-2]

# %%
def get_action(name):
    for act, classes in CLASSES.items():
        for cls in classes:
            if name.lower().find(cls) != -1:
                return act
    return None

# %%
grouped_tracks = {ans: [] for ans in ANSWERS}

for df, target in data:
    action = get_action(target)
    if action:
        grouped_tracks[get_action(target)].append(df)

# %%
def process_track(df, *, track, start=-1, end=-1, cut_ratio=0.2, plotting=True, training=True):
    result_row = pd.Series({'amplitude': None, 'freq_1': None, 'freq_2': None, 'freq_1_amp': None, 'freq_2_amp': None, 'freq': None})
    
    start = int(len(df)*cut_ratio) if start == -1 else start
    end = -int(len(df)*cut_ratio) if end == -1 else end
    
    df = df.applymap(lambda x: str(x).replace(',','.'))
    
    try:
        df['time'] = df['time'].astype(float)
        df['gFx'] = df['gFx'].astype(float)
        df['gFy'] = df['gFy'].astype(float)
        df['gFz'] = df['gFz'].astype(float)
    except Exception as exc:
        logger.error('Cannot process track: %s\n%s\n', exc, track)
        return result_row
    
    print(track)
    cropped_df = df.iloc[start: end]
    acc_df = cropped_df[['gFx', 'gFy', 'gFz']]
    
    # Plotting
    fig, ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9 = [None] * 10
    
    if plotting:
        fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(nrows=3, ncols=3, figsize=(15,10))
    
    if plotting:
        ax1.plot(acc_df['gFx'], c='g')
        ax1.plot(acc_df['gFy'], c='r')
        ax1.plot(acc_df['gFz'], c='b')
    
    mean_acc_v = np.array(acc_df.mean())
    
    origin_acc_v = np.array([0, 0, 1])
    rotation_mat = rotation_matrix_from_vectors(mean_acc_v, origin_acc_v)
    
    def rotate(acc):
        v = rotation_mat @ acc
        return pd.Series({'gFx': v[0], 'gFy': v[1], 'gFz': v[2]})
    
    rotated_acc_df = pd.DataFrame(acc_df.apply(rotate, axis=1))
    
    #np.array(rotated_acc_df.mean())
    rotated_acc_df['gFz'] = rotated_acc_df['gFz'] - 1.0
    
    dt = cropped_df['time'].diff().mean()
    fs = int(1.0 / dt)
    
    if fs == 0:
        return result_row
    
    print("Frequency:", fs)
    
    x = integrate(integrate(rotated_acc_df['gFx'], dt), dt)
    y = integrate(integrate(rotated_acc_df['gFy'], dt), dt)
    z = integrate(integrate(rotated_acc_df['gFz'], dt), dt)
    
    # Plotting
    if plotting:
        ax7.plot(x)
        ax8.plot(y)
        ax9.plot(z)
    
    acc = np.sqrt(acc_df.gFx**2 + acc_df.gFy**2 + acc_df.gFz**2)
    amp = max(acc)-min(acc)
    
    result_row['amplitude'] = amp
    
    if training:
        if get_action(track) not in ANSWERS:
            return None
        result_row['true_ans'] = ANSWERS[get_action(track)]
    
    def process_fft(X, ax):
        frq, yabs = fourier_transform(X, fs)
        # Plotting
        if plotting:
            ax.plot(frq, yabs)
            ax.set_xlim([0, 30])
            ax.set_ylim([0, 0.1])
        return frq, yabs
    
    
    frq, acc_freqs = process_fft(acc.values, ax3)
    acc_freqs_sorted = sorted(zip(frq, acc_freqs), key=lambda x: x[1], reverse=True)
    
    result_row['freq'] = fs
    result_row['freq_1'] = acc_freqs_sorted[1][0]
    result_row['freq_2'] = acc_freqs_sorted[2][0]
    result_row['freq_1_amp'] = acc_freqs_sorted[1][1]
    result_row['freq_2_amp'] = acc_freqs_sorted[2][1]
    
    process_fft(acc_df['gFx'].values, ax4)
    process_fft(acc_df['gFy'].values, ax5)
    process_fft(acc_df['gFz'].values, ax6)
    
    # Plotting
    if plotting:
        ax2.plot(acc)
        plt.show()
    
    return result_row

# %%
def get_track_num(target):
    return int(target.split('_')[1].split('.')[0])

# %%
testing_data = sorted(testing_data, key=lambda x: get_track_num(x[1]))

# %%
def df_for_training(raw_data):
    X_df = pd.DataFrame()

    for track_df, target in raw_data:
        track_row = process_track(track_df, track=target, plotting=False, training=True)
        X_df = X_df.append(track_row, ignore_index=True)
    return X_df

# %%
def df_for_testing(raw_data):
    X_df = pd.DataFrame()

    for track_df, target in raw_data:
        track_row = process_track(track_df, track=target, plotting=False, training=False)
        track_row['track_num'] = get_track_num(target)
        X_df = X_df.append(track_row, ignore_index=True)
    return X_df

# %%
X_df = df_for_training(data)
# Out:
# Aleksandr Pogodaev - Погодаев_бег_1
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_бег_2
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_бег_3
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_бег_4
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_1
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_2
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_3
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_4
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_1
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_2
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_3
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_4
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_1
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_2
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_3
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_4
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_ходьба_1
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_ходьба_2
# Frequency: 499
# Aleksandr Pogodaev - Погодаев_ходьба_3
# Frequency: 498
# Aleksandr Pogodaev - Погодаев_ходьба_4
# Frequency: 499
# Alina Arslanova - Арсланова_поездки в автомобиле_1.uu
# Frequency: 400
# Alina Arslanova - Арсланова_поездки в автомобиле_2.uu
# Frequency: 400
# Alina Arslanova - Арсланова_поездки в автомобиле_3.uu
# Frequency: 398
# Alina Arslanova - Арсланова_стояние на месте_1.uu
# Frequency: 400
# Alina Arslanova - Арсланова_стояние на месте_2.uu
# Frequency: 400
# Alina Arslanova - Арсланова_стояние на месте_3.uu
# Frequency: 400
# Alina Arslanova - Арсланова_стояние на месте_4.uu
# Frequency: 400
# Anatolii - paru4ik_stay_1.csv
# Frequency: 99
# Anatolii - paru4ik_stay_2.csv
# Frequency: 99
# Anatolii - paru4ik_stay_3.csv
# Frequency: 99
# Anatolii - paru4ik_stay_4.csv
# Frequency: 99
# Anatolii - paru4ik_лестница_1.csv
# Frequency: 99
# Anatolii - paru4ik_лестница_2.csv
# Frequency: 99
# Anatolii - paru4ik_лестница_3.csv
# Frequency: 99
# Anatolii - paru4ik_лестница_4.csv
# Frequency: 99
# Dima Sokolov - Соколов_Бег_1.csv
# Frequency: 145
# Dima Sokolov - Соколов_Стояние_2.csv
# Frequency: 148
# Dima Sokolov - Соколов_Ходьба_4.csv
# Frequency: 150
# Dmitry - Колунтаев_автобус_1.csv
# Frequency: 16790
# Dmitry - Колунтаев_автомобиль_1.csv
# Frequency: 17605
# Dmitry - Колунтаев_автомобиль_2.csv
# Frequency: 19516
# Dmitry - Колунтаев_лестница_1.csv
# Frequency: 8103
# Dmitry - Колунтаев_лестница_2.csv
# Frequency: 7696
# Dmitry - Колунтаев_ходьба_1.csv
# Frequency: 13
# Dmitry - Колунтаев_ходьба_2.csv
# Frequency: 7995
# Dmitry - Колунтаев_ходьба_3.csv
# Frequency: 8161
# Evgenia Mescheryakova - emesch_бег_1.uu
# Frequency: 407
# Evgenia Mescheryakova - emesch_бег_2.uu
# Frequency: 407
# Evgenia Mescheryakova - emesch_бег_3.uu
# Frequency: 407
# Evgenia Mescheryakova - emesch_бег_4.uu
# Frequency: 407
# Evgenia Mescheryakova - emesch_бег_5.uu
# Frequency: 1196
# Evgenia Mescheryakova - emesch_бег_6.uu
# Frequency: 1251
# Evgenia Mescheryakova - emesch_велосипед_1.uu
# Frequency: 408
# Evgenia Mescheryakova - emesch_велосипед_2.uu
# Frequency: 408
# Evgenia Mescheryakova - emesch_велосипед_3.uu
# Frequency: 458
# Evgenia Mescheryakova - emesch_велосипед_4.uu
# Frequency: 408
# Evgenia Mescheryakova - emesch_лестница_1.uu
# Frequency: 413
# Evgenia Mescheryakova - emesch_стояние_1.uu
# Frequency: 1193
# Evgenia Mescheryakova - emesch_стояние_2.uu
# Frequency: 2096
# Evgenia Mescheryakova - emesch_стояние_3.uu
# Frequency: 2029
# Evgenia Mescheryakova - emesch_стояние_4.uu
# Frequency: 1584
# Evgenia Mescheryakova - emesch_стояние_5.uu
# Frequency: 408
# Evgenia Mescheryakova - emesch_стояние_6.uu
# Frequency: 1219
# Evgenia Mescheryakova - emesch_ходьба_1.uu
# Frequency: 409
# Evgenia Mescheryakova - emesch_ходьба_2.uu
# Frequency: 408
# Evgenia Mescheryakova - emesch_ходьба_3.uu
# Frequency: 408
# Evgenia Mescheryakova - emesch_ходьба_4.uu
# Frequency: 407
# Evgenia Mescheryakova - emesch_ходьба_5.uu
# Frequency: 407
# Flegontov Ivan - флегонтов_лестница_1
# Frequency: 1959
# Flegontov Ivan - флегонтов_лестница_2
# Frequency: 2111
# Flegontov Ivan - флегонтов_лестница_3
# Frequency: 2312
# Flegontov Ivan - флегонтов_лестница_4
# Frequency: 3216
# Flegontov Ivan - флегонтов_стояние_1
# Frequency: 1382
# Flegontov Ivan - флегонтов_стояние_2
# Frequency: 500
# Flegontov Ivan - флегонтов_стояние_3
# Frequency: 2743
# Flegontov Ivan - флегонтов_стояние_4
# Frequency: 2630
# Flegontov Ivan - флегонтов_ходьба_1
# Frequency: 1760
# Flegontov Ivan - флегонтов_ходьба_2
# Frequency: 1648
# Flegontov Ivan - флегонтов_ходьба_3
# Frequency: 1950
# Flegontov Ivan - флегонтов_ходьба_4
# Frequency: 1633
# Infraeconomy Expert 1 - Филиппова_стояние_1.csv
# Frequency: 99
# Infraeconomy Expert 1 - Филиппова_стояние_2.csv
# Frequency: 99
# Infraeconomy Expert 1 - Филиппова_стояние_3.csv
# Frequency: 99
# Infraeconomy Expert 1 - Филиппова_стояние_4.csv
# Frequency: 99
# Infraeconomy Expert 1 - Филиппова_ходьба_1.csv
# Frequency: 99
# Infraeconomy Expert 1 - Филиппова_ходьба_2.csv
# Frequency: 13
# Infraeconomy Expert 1 - Филиппова_ходьба_3.csv
# Frequency: 99
# Infraeconomy Expert 1 - Филиппова_ходьба_4.csv
# Frequency: 99
# Kirill - reekuu_бег_01.csv
# Frequency: 99
# Kirill - reekuu_бег_02.csv
# Frequency: 26
# Kirill - reekuu_бег_03.csv
# Frequency: 99
# Kirill - reekuu_бег_04.csv
# Frequency: 99
# Kirill - reekuu_велосипед_01.csv
# Frequency: 99
# Kirill - reekuu_велосипед_02.csv
# Frequency: 41
# Kirill - reekuu_велосипед_03.csv
# Frequency: 37
# Kirill - reekuu_велосипед_04.csv
# Frequency: 99
# Kirill - reekuu_лестница_01.csv
# Frequency: 99
# Kirill - reekuu_лестница_02.csv
# Frequency: 99
# Kirill - reekuu_лестница_03.csv
# Frequency: 99
# Kirill - reekuu_лестница_04.csv
# Frequency: 99
# Kirill - reekuu_стояние_01.csv
# Frequency: 99
# Kirill - reekuu_стояние_02.csv
# Frequency: 99
# Kirill - reekuu_стояние_03.csv
# Frequency: 99
# Kirill - reekuu_стояние_04.csv
# Frequency: 99
# Kirill - reekuu_ходьба_01.csv
# Frequency: 100
# Kirill - reekuu_ходьба_02.csv
# Frequency: 99
# Kirill - reekuu_ходьба_03.csv
# Frequency: 99
# Kirill - reekuu_ходьба_04.csv
# Frequency: 99
# KirillKorolev - Королев_лестница_1
# Frequency: 100
# KirillKorolev - Королев_лестница_2
# Frequency: 100
# KirillKorolev - Королев_лестница_3
# Frequency: 100
# KirillKorolev - Королев_стояние_1
# Frequency: 100
# KirillKorolev - Королев_стояние_2
# Frequency: 100
# KirillKorolev - Королев_ходьба_1
# Frequency: 100
# KirillKorolev - Королев_ходьба_2
# Frequency: 100
# KirillKorolev - Королев_ходьба_3
# Frequency: 100
# KirillKorolev - Королев_ходьба_4
# Frequency: 100
# Maria Shcherbina - Щербина_подъем_1
# Frequency: 399
# Maria Shcherbina - Щербина_подъем_2
# Frequency: 930
# Maria Shcherbina - Щербина_подъем_3
# Frequency: 397
# Maria Shcherbina - Щербина_подъем_4
# Frequency: 892
# Maria Shcherbina - Щербина_подъем_5
# Frequency: 396
# Maria Shcherbina - Щербина_стояние_1
# Frequency: 3474
# Maria Shcherbina - Щербина_стояние_2
# Frequency: 1212
# Maria Shcherbina - Щербина_стояние_3
# Frequency: 1491
# Maria Shcherbina - Щербина_стояние_4
# Frequency: 3574
# Maria Shcherbina - Щербина_стояние_5
# Frequency: 3581
# Maria Shcherbina - Щербина_ходьба_1
# Frequency: 396
# Maria Shcherbina - Щербина_ходьба_2
# Frequency: 396
# Maria Shcherbina - Щербина_ходьба_3
# Frequency: 396
# Maria Shcherbina - Щербина_ходьба_4
# Frequency: 1625
# Maria Shcherbina - Щербина_ходьба_5
# Frequency: 1853
# Maxim Mozgovoy - mmozgovoy_бег_1.csv
# Frequency: 100
# Maxim Mozgovoy - mmozgovoy_бег_2.csv
# Frequency: 100
# Maxim Mozgovoy - mmozgovoy_бег_3.csv
# Frequency: 10577
# Maxim Mozgovoy - mmozgovoy_бег_4.csv
# Frequency: 17
# Maxim Mozgovoy - mmozgovoy_лестница_1.csv
# Frequency: 11628
# Maxim Mozgovoy - mmozgovoy_лестница_2.csv
# Frequency: 13754
# Maxim Mozgovoy - mmozgovoy_лестница_3.csv
# Frequency: 11
# Maxim Mozgovoy - mmozgovoy_лестница_4.csv
# Frequency: 11769
# Maxim Mozgovoy - mmozgovoy_стояние_1.csv
# Frequency: 100
# Maxim Mozgovoy - mmozgovoy_стояние_2.csv
# Frequency: 100
# Maxim Mozgovoy - mmozgovoy_стояние_3.csv
# Frequency: 100
# Maxim Mozgovoy - mmozgovoy_стояние_4.csv
# Frequency: 14411
# Maxim Mozgovoy - mmozgovoy_ходьба_1.csv
# Frequency: 100
# Maxim Mozgovoy - mmozgovoy_ходьба_2.csv
# Frequency: 14828
# Maxim Mozgovoy - mmozgovoy_ходьба_3.csv
# Frequency: 12679
# Maxim Mozgovoy - mmozgovoy_ходьба_4.csv
# Frequency: 12101
# Olga - OVP_стояние_на_месте.csv
# Frequency: 102
# Olga - OVP_ходьба.csv
# Frequency: 102
# Polina Roshchina - Рощина_автомобиль_1.csv
# Frequency: 100
# Polina Roshchina - Рощина_автомобиль_2.csv
# Frequency: 100
# Polina Roshchina - Рощина_автомобиль_3.csv
# Frequency: 100
# Polina Roshchina - Рощина_автомобиль_4.csv
# Frequency: 100
# Polina Roshchina - Рощина_бег_1.csv
# Frequency: 7
# Polina Roshchina - Рощина_бег_2.csv
# Frequency: 821
# Polina Roshchina - Рощина_бег_3.csv
# Frequency: 1829
# Polina Roshchina - Рощина_бег_4.csv
# Frequency: 16
# Polina Roshchina - Рощина_велосипед_1.csv
# Frequency: 453
# Polina Roshchina - Рощина_велосипед_2.csv
# Frequency: 7
# Polina Roshchina - Рощина_велосипед_3.csv
# Frequency: 1558
# Polina Roshchina - Рощина_лестница_1.csv
# Frequency: 7
# Polina Roshchina - Рощина_лестница_2.csv
# Frequency: 619
# Polina Roshchina - Рощина_лестница_3.csv
# Frequency: 100
# Polina Roshchina - Рощина_лестница_4.csv
# Frequency: 100
# Polina Roshchina - Рощина_стояние_1.csv
# Frequency: 13
# Polina Roshchina - Рощина_стояние_2.csv
# Frequency: 100
# Polina Roshchina - Рощина_стояние_3.csv
# Frequency: 100
# Polina Roshchina - Рощина_стояние_4.csv
# Frequency: 76
# Polina Roshchina - Рощина_ходьба_1.csv
# Frequency: 66
# Polina Roshchina - Рощина_ходьба_2.csv
# Frequency: 100
# Polina Roshchina - Рощина_ходьба_3.csv
# Frequency: 100
# Polina Roshchina - Рощина_ходьба_4.csv
# Frequency: 96
# Rzhevskii Anatolii - paru4ik_ходьба_1.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_ходьба_2.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_ходьба_3.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_ходьба_4.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_ходьба_5.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_электричка_1.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_электричка_2.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_электричка_3.csv
# Frequency: 99
# Rzhevskii Anatolii - paru4ik_электричка_4.csv
# Frequency: 99
# Sergey - DrM_автомобиль_1
# Frequency: 198
# Sergey - DrM_автомобиль_2
# Frequency: 198
# Sergey - DrM_автомобиль_3
# Frequency: 198
# Sergey - DrM_автомобиль_4
# Frequency: 198
# Sergey - DrM_бег_1
# Frequency: 198
# Sergey - DrM_бег_2
# Frequency: 199
# Sergey - DrM_бег_3
# Frequency: 198
# Sergey - DrM_бег_4
# Frequency: 199
# Sergey - DrM_лестница_1
# Frequency: 199
# Sergey - DrM_лестница_2
# Frequency: 198
# Sergey - DrM_лестница_3
# Frequency: 198
# Sergey - DrM_лестница_4
# Frequency: 198
# Sergey - DrM_стояние_1
# Frequency: 199
# Sergey - DrM_стояние_2
# Frequency: 198
# Sergey - DrM_стояние_3
# Frequency: 198
# Sergey - DrM_стояние_4
# Frequency: 199
# Sergey - DrM_ходьба_1
# Frequency: 198
# Sergey - DrM_ходьба_2
# Frequency: 198
# Sergey - DrM_ходьба_3
# Frequency: 198
# Sergey - DrM_ходьба_4
# Frequency: 199
# Vladimir - Бегемот_ходьба_1
# Frequency: 135
# anatolii - paru4ik_running_1.csv
# Frequency: 99
# anatolii - paru4ik_running_2.csv
# Frequency: 99
# anatolii - paru4ik_running_3.csv
# Frequency: 99
# anatolii - paru4ik_running_4.csv
# Frequency: 99
# dimiii - 2021-07-23 20.51.28 - буба_велосипед_1.csv
# Frequency: 303
# dimiii - буба_автомобиль_1.csv
# Frequency: 500
# dimiii - буба_бег_1.csv
# Frequency: 500
# dimiii - буба_бег_2.csv
# Frequency: 500
# dimiii - буба_бег_3.csv
# Frequency: 499
# dimiii - буба_велосипед_2.csv
# Frequency: 500
# dimiii - буба_велосипед_3.csv
# Frequency: 499
# dimiii - буба_велосипед_4.csv
# Frequency: 500
# dimiii - буба_лестница_1.csv
# Frequency: 499
# dimiii - буба_лестница_3.csv
# Frequency: 499
# dimiii - буба_лестница_4.csv
# Frequency: 499
# dimiii - буба_стояние_1.csv
# Frequency: 500
# dimiii - буба_стояние_2.csv
# Frequency: 490
# dimiii - буба_стояние_3.csv
# Frequency: 500
# dimiii - буба_стояние_6.csv
# Frequency: 500
# dimiii - буба_ходьба_1.csv
# Frequency: 499
# dimiii - буба_ходьба_2.csv
# Frequency: 500
# dimiii - буба_ходьба_3.csv
# Frequency: 500
# tdiff - tdiff_вел_01
# Frequency: 95
# tdiff - tdiff_вел_02
# Frequency: 99
# tdiff - tdiff_вел_03
# Frequency: 99
# tdiff - tdiff_вел_04
# Frequency: 99
# tdiff - tdiff_вел_05
# Frequency: 99
# Алексей - Меглей_бег_1
# Frequency: 499
# Алексей - Меглей_бег_2
# Frequency: 500
# Алексей - Меглей_бег_3
# Frequency: 500
# Алексей - Меглей_бег_4
# Frequency: 500
# Алексей - Меглей_лестница_1
# Frequency: 500
# Алексей - Меглей_лестница_2
# Frequency: 500
# Алексей - Меглей_лестница_3
# Frequency: 500
# Алексей - Меглей_лестница_4
# Frequency: 500
# Алексей - Меглей_стояние_1
# Frequency: 500
# Алексей - Меглей_стояние_2
# Frequency: 500
# Алексей - Меглей_стояние_3
# Frequency: 500
# Алексей - Меглей_стояние_4
# Frequency: 500
# Алексей - Меглей_ходьба_1
# Frequency: 500
# Алексей - Меглей_ходьба_2
# Frequency: 500
# Алексей - Меглей_ходьба_3
# Frequency: 500
# Алексей - Меглей_ходьба_4
# Frequency: 438
# Алексей - Меглей_ходьба_5
# Frequency: 500
# Алмаз - Гизатуллин_бег_01
# Frequency: 397
# Алмаз - Гизатуллин_бег_02
# Frequency: 397
# Алмаз - Гизатуллин_бег_03
# Frequency: 397
# Алмаз - Гизатуллин_бег_04
# Frequency: 397
# Алмаз - Гизатуллин_велосипед_01
# Frequency: 398
# Алмаз - Гизатуллин_велосипед_02
# Frequency: 398
# Алмаз - Гизатуллин_велосипед_04
# Frequency: 398
# Алмаз - Гизатуллин_велосипед_05
# Frequency: 398
# Алмаз - Гизатуллин_лестница_01
# Frequency: 397
# Алмаз - Гизатуллин_лестница_02
# Frequency: 397
# Алмаз - Гизатуллин_лестница_03
# Frequency: 397
# Алмаз - Гизатуллин_лестница_04
# Frequency: 397
# Алмаз - Гизатуллин_стояние_01
# Frequency: 399
# Алмаз - Гизатуллин_стояние_02
# Frequency: 399
# Алмаз - Гизатуллин_стояние_03
# Frequency: 398
# Алмаз - Гизатуллин_стояние_04
# Frequency: 398
# Алмаз - Гизатуллин_ходьба_01
# Frequency: 397
# Алмаз - Гизатуллин_ходьба_02
# Frequency: 397
# Алмаз - Гизатуллин_ходьба_03
# Frequency: 397
# Алмаз - Гизатуллин_ходьба_04
# Frequency: 397
# Анастасия - Анастасия_бег_1.csv
# Frequency: 100
# Анастасия - Анастасия_бег_2.csv
# Frequency: 100
# Анастасия - Анастасия_бег_3.csv
# Frequency: 100
# Анастасия - Анастасия_бег_4.csv
# Frequency: 100
# Анастасия - Анастасия_подъем по лестнице_2.csv
# Frequency: 74
# Анастасия - Анастасия_подъем по лестнице_3.csv
# Frequency: 100
# Анастасия - Анастасия_подъем по лестнице_4.csv
# Frequency: 100
# Анастасия - Анастасия_подъем по лестнице_5.csv
# Frequency: 76
# Анастасия - Анастасия_поездка в автомобиле_1.csv
# Frequency: 100
# Анастасия - Анастасия_стояние на месте_1.csv
# Frequency: 100
# Анастасия - Анастасия_стояние на месте_2.csv
# Frequency: 100
# Анастасия - Анастасия_стояние на месте_3.csv
# Frequency: 100
# Анастасия - Анастасия_стояние на месте_5.csv
# Frequency: 100
# Анастасия - Анастасия_ходьба_1.csv
# Frequency: 100
# Анастасия - Анастасия_ходьба_3.csv
# Frequency: 100
# Анастасия - Анастасия_ходьба_4.csv
# Frequency: 100
# Анастасия - Анастасия_ходьба_5.csv
# Frequency: 77
# Анна - Созонтова_лестница_1.csv
# Frequency: 99
# Анна - Созонтова_лестница_2.csv
# Frequency: 100
# Анна - Созонтова_лестница_3.csv
# Frequency: 100
# Анна - Созонтова_лестница_4.csv
# Frequency: 100
# Анна - Созонтова_стояние_1.csv
# Frequency: 78
# Анна - Созонтова_стояние_2.csv
# Frequency: 77
# Анна - Созонтова_стояние_3.csv
# Frequency: 100
# Анна - Созонтова_стояние_4.csv
# Frequency: 98
# Анна - Созонтова_ходьба_1.csv
# Frequency: 100
# Анна - Созонтова_ходьба_2.csv
# Frequency: 100
# Анна - Созонтова_ходьба_3.csv
# Frequency: 100
# Анна - Созонтова_ходьба_4.csv
# Frequency: 100
# Анна Сухова - Сухова_стояние_1.csv
# Frequency: 99
# Анна Сухова - Сухова_стояние_2.csv
# Frequency: 100
# Анна Сухова - Сухова_ходьба_1.csv
# Frequency: 99
# Анна Сухова - Сухова_ходьба_2.csv
# Frequency: 99
# Валерия - Лезжова_бег_1.csv
# Frequency: 48
# Валерия - Лезжова_бег_2.csv
# Frequency: 99
# Валерия - Лезжова_бег_3.csv
# Frequency: 99
# Валерия - Лезжова_бег_4.csv
# Frequency: 76
# Валерия - Лезжова_лестница_1.csv
# Frequency: 99
# Валерия - Лезжова_лестница_2.csv
# Frequency: 59
# Валерия - Лезжова_лестница_3.csv
# Frequency: 10
# Валерия - Лезжова_лестница_4.csv
# Frequency: 7738
# Валерия - Лезжова_стояние_1.csv
# Frequency: 77
# Валерия - Лезжова_стояние_2.csv
# Frequency: 99
# Валерия - Лезжова_стояние_3.csv
# Frequency: 75
# Валерия - Лезжова_стояние_4.csv
# Frequency: 99
# Валерия - Лезжова_ходьба_1.csv
# Frequency: 16
# Валерия - Лезжова_ходьба_2.csv
# Frequency: 8429
# Валерия - Лезжова_ходьба_3.csv
# Frequency: 47
# Валерия - Лезжова_ходьба_4.csv
# Frequency: 14
# Геннадий - бгм_лестница_1.csv
# Frequency: 846
# Геннадий - бгм_лестница_2.csv
# Frequency: 845
# Геннадий - бгм_лестница_3.csv
# Frequency: 845
# Геннадий - бгм_лестница_4.csv
# Frequency: 845
# Геннадий - бгм_стояние_1.csv
# Frequency: 846
# Геннадий - бгм_стояние_2.csv
# Frequency: 845
# Геннадий - бгм_стояние_3.csv
# Frequency: 845
# Геннадий - бгм_стояние_4.csv
# Frequency: 846
# Геннадий - бгм_ходьба_1.csv
# Frequency: 845
# Геннадий - бгм_ходьба_2.csv
# Frequency: 845
# Геннадий - бгм_ходьба_3.csv
# Frequency: 846
# Геннадий - бгм_ходьба_4.csv
# Frequency: 845
# Данила Котельников - Котельников_автомобиль_1.csv
# Frequency: 100
# Данила Котельников - Котельников_автомобиль_2.csv
# Frequency: 100
# Данила Котельников - Котельников_автомобиль_3.csv
# Frequency: 100
# Данила Котельников - Котельников_автомобиль_4.csv
# Frequency: 100
# Данила Котельников - Котельников_бег_1.csv
# Frequency: 100
# Данила Котельников - Котельников_бег_2.csv
# Frequency: 100
# Данила Котельников - Котельников_бег_3.csv
# Frequency: 100
# Данила Котельников - Котельников_бег_4.csv
# Frequency: 100
# Данила Котельников - Котельников_велосипед_1.csv
# Frequency: 23
# Данила Котельников - Котельников_велосипед_2.csv
# Frequency: 100
# Данила Котельников - Котельников_велосипед_3.csv
# Frequency: 100
# Данила Котельников - Котельников_велосипед_4.csv
# Frequency: 100
# Данила Котельников - Котельников_стояние_1.csv
# Frequency: 100
# Данила Котельников - Котельников_стояние_2.csv
# Frequency: 100
# Данила Котельников - Котельников_стояние_3.csv
# Frequency: 100
# Данила Котельников - Котельников_стояние_4.csv
# Frequency: 100
# Данила Котельников - Котельников_ходьба_1.csv
# Frequency: 100
# Данила Котельников - Котельников_ходьба_2.csv
# Frequency: 100
# Данила Котельников - Котельников_ходьба_3.csv
# Frequency: 100
# Данила Котельников - Котельников_ходьба_4.csv
# Frequency: 100
# Дария - ВоробьеваДВ_хотьба_1
# Frequency: 36
# Дария - ВоробьеваДВ_хотьба_2
# Frequency: 33
# Дария - ВоробьеваДВ_хотьба_3
# Frequency: 44
# Дария - ВоробьеваДВ_хотьба_4
# Frequency: 45
# Екатерина Митрохина - Митрохина_бег_1.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_бег_2.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_бег_3.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_бег_4.csv
# Frequency: 74
# Екатерина Митрохина - Митрохина_велосипед_1.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_велосипед_2.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_велосипед_3.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_велосипед_4.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_стояние_1.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_стояние_2.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_стояние_3.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_стояние_4.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_ходьба_1.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_ходьба_2.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_ходьба_3.csv
# Frequency: 99
# Екатерина Митрохина - Митрохина_ходьба_4.csv
# Frequency: 99
# Илья - Максименко_Лестница_1.csv
# Frequency: 99
# Илья - Максименко_Лестница_2.csv
# Frequency: 99
# Илья - Максименко_Лестница_3.csv
# Frequency: 99
# Илья - Максименко_Стояние_1.csv
# Frequency: 99
# Илья - Максименко_Стояние_2.csv
# Frequency: 99
# Илья - Максименко_Стояние_3.csv
# Frequency: 99
# Илья - Максименко_Стояние_4.csv
# Frequency: 99
# Илья - Максименко_Ходьба_1.csv
# Frequency: 99
# Илья - Максименко_Ходьба_2.csv
# Frequency: 99
# Илья - Максименко_Ходьба_3.csv
# Frequency: 99
# Илья - Максименко_Ходьба_4.csv
# Frequency: 99
# Кермен - малашева_бег_1.csv
# Frequency: 99
# Кермен - малашева_бег_2.csv
# Frequency: 99
# Кермен - малашева_бег_3.csv
# Frequency: 99
# Кермен - малашева_бег_4.csv
# Frequency: 99
# Кермен - малашева_лестница_1.csv
# Frequency: 99
# Кермен - малашева_лестница_2.csv
# Frequency: 99
# Кермен - малашева_лестница_3.csv
# Frequency: 99
# Кермен - малашева_лестница_4.csv
# Frequency: 99
# Кермен - малашева_стояние_1.csv
# Frequency: 99
# Кермен - малашева_стояние_2.csv
# Frequency: 99
# Кермен - малашева_стояние_3.csv
# Frequency: 99
# Кермен - малашева_стояние_4.csv
# Frequency: 100
# Кермен - малашева_ходьба_1.csv
# Frequency: 99
# Кермен - малашева_ходьба_2.csv
# Frequency: 99
# Кермен - малашева_ходьба_3.csv
# Frequency: 99
# Кермен - малашева_ходьба_4.csv
# Frequency: 99
# Мажорова Инна - Мажорова-велосипед_1
# Frequency: 403
# Мажорова Инна - Мажорова_велосипед_2
# Frequency: 402
# Максим - 2021-07-24 18.24.16 - Лобода_ходьба_1
# Frequency: 99
# Максим - Лобода_бег_1
# Frequency: 99
# Максим - Лобода_бег_2
# Frequency: 99
# Максим - Лобода_бег_3
# Frequency: 100
# Максим - Лобода_бег_4
# Frequency: 99
# Максим - Лобода_лестница_1
# Frequency: 99
# Максим - Лобода_лестница_2
# Frequency: 99
# Максим - Лобода_лестница_3
# Frequency: 99
# Максим - Лобода_лестница_4
# Frequency: 99
# Максим - Лобода_стояние_1
# Frequency: 99
# Максим - Лобода_стояние_2
# Frequency: 99
# Максим - Лобода_стояние_3
# Frequency: 99
# Максим - Лобода_стояние_4
# Frequency: 99
# Максим - Лобода_ходьба_1
# Frequency: 95
# Максим - Лобода_ходьба_2
# Frequency: 99
# Максим - Лобода_ходьба_3
# Frequency: 99
# Максим - Лобода_ходьба_4
# Frequency: 99
# Михаил - Mstr_лестница_1.csv
# Frequency: 207
# Михаил - Mstr_ходьба_1.csv
# Frequency: 208
# Наталья - Югансон_бег_1
# Frequency: 249
# Наталья - Югансон_бег_2
# Frequency: 249
# Наталья - Югансон_бег_3
# Frequency: 250
# Наталья - Югансон_бег_4
# Frequency: 250
# Наталья - Югансон_лестница_2
# Frequency: 249
# Наталья - Югансон_лестница_3
# Frequency: 249
# Наталья - Югансон_лестница_4
# Frequency: 249
# Наталья - Югансон_лестница_5
# Frequency: 249
# Наталья - Югансон_стояние_1
# Frequency: 249
# Наталья - Югансон_стояние_2
# Frequency: 249
# Наталья - Югансон_стояние_3
# Frequency: 249
# Наталья - Югансон_стояние_4
# Frequency: 250
# Наталья - Югансон_ходьба_1
# Frequency: 249
# Наталья - Югансон_ходьба_2
# Frequency: 250
# Наталья - Югансон_ходьба_3
# Frequency: 249
# Наталья - Югансон_ходьба_4
# Frequency: 249
# Никита - Бажов_Ходьба_1.csv
# Frequency: 99
# Никита - Бажов_лестница_1.csv
# Frequency: 99
# Никита - Бажов_ходьба_2.csv
# Frequency: 99
# Никита - Никита_М_автобус_1
# Frequency: 499
# Никита - Никита_М_автобус_2
# Frequency: 500
# Никита - Никита_М_автобус_3
# Frequency: 500
# Никита - Никита_М_автобус_4
# Frequency: 499
# Никита - Никита_М_стояние_1
# Frequency: 500
# Никита - Никита_М_стояние_2
# Frequency: 499
# Никита - Никита_М_стояние_3
# Frequency: 499
# Никита - Никита_М_стояние_4
# Frequency: 469
# Никита - Никита_М_ходьба_1
# Frequency: 500
# Никита - Никита_М_ходьба_2
# Frequency: 499
# Никита - Никита_М_ходьба_3
# Frequency: 499
# Никита - Никита_М_ходьба_4
# Frequency: 499
# Оксана - Oksana_stairs_1.csv
# Frequency: 99
# Оксана - Oksana_stairs_2.csv
# Frequency: 99
# Оксана - Oksana_stairs_3.csv
# Frequency: 99
# Оксана - Oksana_stairs_4.csv
# Frequency: 99
# Оксана - Oksana_stand_1.csv
# Frequency: 99
# Оксана - Oksana_stand_2.csv
# Frequency: 99
# Оксана - Oksana_stand_3.csv
# Frequency: 99
# Оксана - Oksana_stand_4.csv
# Frequency: 99
# Олег Сахно - olegsakhno_бег_1.csv
# Frequency: 11083
# Олег Сахно - olegsakhno_бег_2.csv
# Frequency: 9
# Олег Сахно - olegsakhno_бег_3.csv
# Frequency: 10
# Олег Сахно - olegsakhno_бег_4.csv
# Frequency: 9
# Олег Сахно - olegsakhno_лестница_1.csv
# Frequency: 13905
# Олег Сахно - olegsakhno_лестница_2.csv
# Frequency: 15679
# Олег Сахно - olegsakhno_лестница_3.csv
# Frequency: 14557
# Олег Сахно - olegsakhno_лестница_4.csv
# Frequency: 14423
# Олег Сахно - olegsakhno_стояние_1.csv
# Frequency: 12
# Олег Сахно - olegsakhno_стояние_2.csv
# Frequency: 14559
# Олег Сахно - olegsakhno_стояние_3.csv
# Frequency: 14352
# Олег Сахно - olegsakhno_стояние_4.csv
# Frequency: 12
# Олег Сахно - olegsakhno_ходьба_1.csv
# Frequency: 13
# Олег Сахно - olegsakhno_ходьба_2.csv
# Frequency: 11
# Олег Сахно - olegsakhno_ходьба_3.csv
# Frequency: 3081
# Олег Сахно - olegsakhno_ходьба_4.csv
# Frequency: 15011
# Олег Уфа - олегуфа_бег_1
# Frequency: 797
# Олег Уфа - олегуфа_бег_2
# Frequency: 1582
# Олег Уфа - олегуфа_бег_3
# Frequency: 396
# Олег Уфа - олегуфа_бег_4
# Frequency: 1139
# Олег Уфа - олегуфа_лестница_1
# Frequency: 397
# Олег Уфа - олегуфа_лестница_2
# Frequency: 2229
# Олег Уфа - олегуфа_лестница_3
# Frequency: 1704
# Олег Уфа - олегуфа_лестница_4
# Frequency: 1757
# Олег Уфа - олегуфа_стояние_1
# Frequency: 2248
# Олег Уфа - олегуфа_стояние_2
# Frequency: 1468
# Олег Уфа - олегуфа_стояние_3
# Frequency: 2881
# Олег Уфа - олегуфа_стояние_4
# Frequency: 397
# Олег Уфа - олегуфа_ходьба_1
# Frequency: 404
# Олег Уфа - олегуфа_ходьба_2
# Frequency: 403
# Олег Уфа - олегуфа_ходьба_3
# Frequency: 1684
# Олег Уфа - олегуфа_ходьба_4
# Frequency: 2195
# Ольга Сучкова - МитинаОВ_автобус_1.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_автобус_2.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_автобус_3.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_автобус_4.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_лестница_1.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_лестница_2.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_лестница_3.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_лестница_4.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_метро_1.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_метро_2.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_метро_3.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_метро_4.csv
# Frequency: 99
# Ольга Сучкова - МитинаОВ_ходьба_1.csv
# Frequency: 21
# Ольга Сучкова - МитинаОВ_ходьба_2.csv
# Frequency: 78
# Ольга Сучкова - МитинаОВ_ходьба_3.csv
# Frequency: 549
# Ольга Сучкова - МитинаОВ_ходьба_4.csv
# Frequency: 527
# Павел Зеленский - zelenskii_метро_1
# Frequency: 251
# Павел Зеленский - zelenskii_метро_2
# Frequency: 251
# Павел Зеленский - zelenskii_метро_3
# Frequency: 251
# Павел Зеленский - zelenskii_метро_4
# Frequency: 251
# Павел Зеленский - zelenskii_стояние_1
# Frequency: 251
# Павел Зеленский - zelenskii_стояние_2
# Frequency: 251
# Павел Зеленский - zelenskii_стояние_3
# Frequency: 251
# Павел Зеленский - zelenskii_стояние_4
# Frequency: 251
# Пыркова - Пыркова_лестница_1.csv
# Frequency: 100
# Пыркова - Пыркова_стояние_1.csv
# Frequency: 100
# Пыркова - Пыркова_ходьба_1.csv
# Frequency: 100
# Родион - Имаев_стояние_1.csv
# Frequency: 100
# Родион - Имаев_ходьба_1.csv
# Frequency: 100
# Родион - Имаев_ходьба_2.csv
# Frequency: 100
# Родион - Имаев_ходьба_3.csv
# Frequency: 100
# Рома - романоид_бег_1.csv
# Frequency: 99
# Рома - романоид_бег_2.csv
# Frequency: 99
# Рома - романоид_бег_3.csv
# Frequency: 101
# Рома - романоид_бег_4.csv
# Frequency: 101
# Рома - романоид_велосипед_1.csv
# Frequency: 99
# Рома - романоид_велосипед_2.csv
# Frequency: 99
# Рома - романоид_велосипед_3.csv
# Frequency: 76
# Рома - романоид_велосипед_4.csv
# Frequency: 100
# Рома - романоид_стояние_1.csv
# Frequency: 100
# Рома - романоид_стояние_2.csv
# Frequency: 100
# Рома - романоид_стояние_3.csv
# Frequency: 99
# Рома - романоид_стояние_4.csv
# Frequency: 101
# Рома - романоид_ходьба_1.csv
# Frequency: 101
# Рома - романоид_ходьба_2.csv
# Frequency: 100
# Рома - романоид_ходьба_3.csv
# Frequency: 100
# Рома - романоид_ходьба_4.csv
# Frequency: 101
# Сава - Сава_велосипед_1
# Frequency: 799
# Сава - Сава_велосипед_2
# Frequency: 1002
# Сава - Сава_велосипед_3
# Frequency: 1876
# Сава - Сава_велосипед_4
# Frequency: 1369
# Сава - Сава_велосипед_5
# Frequency: 1140
# Сава - Сава_стояние_1
# Frequency: 497
# Сава - Сава_стояние_2
# Frequency: 498
# Сава - Сава_стояние_3
# Frequency: 498
# Сава - Сава_стояние_4
# Frequency: 397
# Сава - Сава_стояние_5
# Frequency: 496
# Сергей - Сергей_автобус_1.csv
# Frequency: 247
# Сергей - Сергей_автобус_2.csv
# Frequency: 247
# Сергей - Сергей_автобус_3.csv
# Frequency: 247
# Сергей - Сергей_автобус_4.csv
# Frequency: 245
# Сергей - Сергей_бег_1.csv
# Frequency: 247
# Сергей - Сергей_бег_2.csv
# Frequency: 248
# Сергей - Сергей_бег_3.csv
# Frequency: 248
# Сергей - Сергей_бег_4.csv
# Frequency: 247
# Сергей - Сергей_лестница_1.csv
# Frequency: 247
# Сергей - Сергей_лестница_2.csv
# Frequency: 172
# Сергей - Сергей_лестница_3.csv
# Frequency: 247
# Сергей - Сергей_лестница_4.csv
# Frequency: 248
# Сергей - Сергей_метро_1.csv
# Frequency: 235
# Сергей - Сергей_метро_2.csv
# Frequency: 236
# Сергей - Сергей_метро_3.csv
# Frequency: 247
# Сергей - Сергей_метро_4.csv
# Frequency: 247
# Сергей - Сергей_стояние_1.csv
# Frequency: 247
# Сергей - Сергей_стояние_2.csv
# Frequency: 247
# Сергей - Сергей_стояние_3.csv
# Frequency: 247
# Сергей - Сергей_стояние_4.csv
# Frequency: 245
# Сергей - Сергей_ходьба_1.csv
# Frequency: 248
# Сергей - Сергей_ходьба_2.csv
# Frequency: 247
# Сергей - Сергей_ходьба_3.csv
# Frequency: 242
# Сергей - Сергей_ходьба_4.csv
# Frequency: 235
# Стелла Абрашева - Абрашева_лестница_1
# Frequency: 994
# Стелла Абрашева - Абрашева_лестница_2
# Frequency: 1139
# Стелла Абрашева - Абрашева_лестница_3
# Frequency: 1494
# Стелла Абрашева - Абрашева_лестница_4
# Frequency: 984
# Стелла Абрашева - Абрашева_лестница_5
# Frequency: 2038
# Стелла Абрашева - Абрашева_стояние_1
# Frequency: 1255
# Стелла Абрашева - Абрашева_стояние_2
# Frequency: 1407
# Стелла Абрашева - Абрашева_стояние_3
# Frequency: 1385
# Стелла Абрашева - Абрашева_стояние_4
# Frequency: 2189
# Стелла Абрашева - Абрашева_стояние_5
# Frequency: 2062
# Стелла Абрашева - Абрашева_ходьба_1
# Frequency: 1071
# Стелла Абрашева - Абрашева_ходьба_2
# Frequency: 2965
# Стелла Абрашева - Абрашева_ходьба_3
# Frequency: 405
# Стелла Абрашева - Абрашева_ходьба_4
# Frequency: 2354
# Стелла Абрашева - Абрашева_ходьба_5
# Frequency: 406
# Сухова Анна - Сухова_стояние_3.csv
# Frequency: 99
# Сухова Анна - Сухова_стояние_4.csv
# Frequency: 99
# Сухова Анна - Сухова_ходьба_3.csv
# Frequency: 99
# Сухова Анна - Сухова_ходьба_4.csv
# Frequency: 99
# Сысков - Сысков_бег_1
# Frequency: 1140
# Сысков - Сысков_бег_2
# Frequency: 1154
# Сысков - Сысков_бег_3
# Frequency: 3960
# Сысков - Сысков_бег_4
# Frequency: 2201
# Сысков - Сысков_велосипед_1
# Frequency: 203
# Сысков - Сысков_велосипед_2
# Frequency: 714
# Сысков - Сысков_велосипед_3
# Frequency: 455
# Сысков - Сысков_велосипед_4
# Frequency: 3384
# Сысков - Сысков_лестница_1
# Frequency: 203
# Сысков - Сысков_лестница_2
# Frequency: 1243
# Сысков - Сысков_лестница_3
# Frequency: 203
# Сысков - Сысков_лестница_4
# Frequency: 203
# Сысков - Сысков_стояние_1
# Frequency: 817
# Сысков - Сысков_стояние_2
# Frequency: 776
# Сысков - Сысков_стояние_3
# Frequency: 203
# Сысков - Сысков_стояние_4
# Frequency: 5154
# Сысков - Сысков_ходьба_1
# Frequency: 251
# Сысков - Сысков_ходьба_2
# Frequency: 879
# Сысков - Сысков_ходьба_3
# Frequency: 1059
# Татьяна - Илюхина_стояние_на_месте_1.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина _подъем_по_лестнице_1.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_подъем_по_лестнице_2.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_подъем_по_лестнице_3.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_подъем_по_лестнице_4.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_поездки_в_автомобиле_1.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_поездки_в_автомобиле_2.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_поездки_в_автомобиле_3.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_поездки_в_автомобиле_4.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_стояние_на_месте_2.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_стояние_на_месте_3.csv
# Frequency: 99
# Татьяна Илюхина - Илюхина_стояние_на_месте_4.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_ходьба_1.csv
# Frequency: 99
# Татьяна Илюхина - Илюхина_ходьба_2.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_ходьба_3.csv
# Frequency: 100
# Татьяна Илюхина - Илюхина_ходьба_4.csv
# Frequency: 100
# Щукина Алина - Щукина Алина_лестница_1.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_лестница_2.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_лестница_3.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_лестница_4.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_стояние_1.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_стояние_2.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_стояние_3.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_стояние_4.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_ходьба_1.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_ходьба_2.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_ходьба_3.csv
# Frequency: 99
# Щукина Алина - Щукина Алина_ходьба_4.csv
# Frequency: 99
# Элтон - Эл_бег_1.csv
# Frequency: 3863
# Элтон - Эл_бег_2.csv
# Frequency: 3877
# Элтон - Эл_бег_3.csv
# Frequency: 2923
# Элтон - Эл_лестница_1.csv
# Frequency: 3969
# Элтон - Эл_стояние_1
# Frequency: 100
# Элтон - Эл_стояние_2
# Frequency: 100
# Элтон - Эл_стояние_3
# Frequency: 100
# Элтон - Эл_стояние_4
# Frequency: 100
# Элтон - Эл_ходьба_1.csv
# Frequency: 4159
# Элтон - Эл_ходьба_2.csv
# Frequency: 3762
# Элтон - Эл_ходьба_3.csv
# Frequency: 3899
# Элтон - Эл_ходьба_4.csv
# Frequency: 3688
# Юрий - юрий_бег_2
# Frequency: 206
# Юрий - юрий_бег_3
# Frequency: 206
# Юрий - юрий_подъем_2
# Frequency: 206
# Юрий - юрий_подъем_3
# Frequency: 206
# Юрий - юрий_покой_2
# Frequency: 206
# Юрий - юрий_покой_3
# Frequency: 206
# Юрий - юрий_покой_4
# Frequency: 206
# Юрий - юрий_покой_5
# Frequency: 206
# Юрий - юрий_самокат_2
# Frequency: 206
# Юрий - юрий_самокат_3
# Frequency: 206
# Юрий - юрий_самокат_4
# Frequency: 206
# Юрий - юрий_самокат_5
# Frequency: 206
# Юрий - юрий_хотьба_2
# Frequency: 206
# Юрий - юрий_хотьба_3
# Frequency: 206
# Юрий - юрий_хотьба_4
# Frequency: 206
# Юрий - юрий_хотьба_5
# Frequency: 206

# %%
X_test_df = df_for_testing(testing_data)
# Out:
# track_0.csv
# Frequency: 207
# track_1.csv
# Frequency: 395
# track_2.csv
# Frequency: 250
# track_3.csv
# Frequency: 499
# track_4.csv
# Frequency: 395
# track_5.csv
# Frequency: 100
# track_6.csv
# Frequency: 99
# track_7.csv
# Frequency: 251
# track_8.csv
# Frequency: 100
# track_9.csv
# Frequency: 198
# track_10.csv
# Frequency: 834
# track_12.csv
# Frequency: 100
# track_13.csv
# Frequency: 98
# track_14.csv
# Frequency: 100
# track_15.csv
# Frequency: 247
# track_16.csv
# Frequency: 99
# track_17.csv
# Frequency: 394
# track_18.csv
# Frequency: 408
# track_19.csv
# Frequency: 99
# track_20.csv
# Frequency: 184
# track_21.csv
# Frequency: 398
# track_22.csv
# Frequency: 500
# track_23.csv
# Frequency: 390
# track_24.csv
# Frequency: 233
# track_25.csv
# Frequency: 98
# track_26.csv
# Frequency: 499
# track_27.csv
# Frequency: 248
# track_28.csv
# Frequency: 100
# track_29.csv
# Frequency: 99
# track_30.csv
# Frequency: 406
# track_31.csv
# Frequency: 500
# track_32.csv
# Frequency: 99
# track_34.csv
# Frequency: 247
# track_35.csv
# Frequency: 407
# track_36.csv
# Frequency: 507
# track_37.csv
# Frequency: 242
# track_38.csv
# Frequency: 100
# track_39.csv
# Frequency: 16626
# track_41.csv
# Frequency: 210
# track_42.csv
# Frequency: 100
# track_43.csv
# Frequency: 255
# track_44.csv
# Frequency: 842
# track_45.csv
# Frequency: 499
# track_46.csv
# Frequency: 199
# track_47.csv
# Frequency: 100
# track_48.csv
# Frequency: 1077
# track_49.csv
# Frequency: 76
# track_50.csv
# Frequency: 295
# track_51.csv
# Frequency: 230
# track_52.csv
# Frequency: 146
# track_53.csv
# Frequency: 100
# track_54.csv
# Frequency: 2680
# track_55.csv
# track_56.csv
# Frequency: 100
# track_57.csv
# Frequency: 400
# track_58.csv
# Frequency: 407
# track_59.csv
# Frequency: 230
# track_61.csv
# Frequency: 100
# track_62.csv
# Frequency: 251
# track_63.csv
# Frequency: 189
# track_64.csv
# Frequency: 412
# track_65.csv
# Frequency: 200
# track_66.csv
# Frequency: 100
# track_67.csv
# Frequency: 499
# track_68.csv
# Frequency: 406
# track_69.csv
# Frequency: 100
# track_70.csv
# Frequency: 99
# track_71.csv
# Frequency: 399
# track_72.csv
# Frequency: 499
# track_73.csv
# Frequency: 249
# track_74.csv
# Frequency: 100
# track_75.csv
# Frequency: 98
# track_77.csv
# Frequency: 389
# track_79.csv
# Frequency: 100
# track_80.csv
# Frequency: 198
# track_81.csv
# Frequency: 839
# track_82.csv
# Frequency: 499
# track_83.csv
# Frequency: 100
# track_84.csv
# Frequency: 405
# track_85.csv
# Frequency: 99
# track_86.csv
# Frequency: 194
# track_87.csv
# Frequency: 506
# track_88.csv
# Frequency: 99
# track_89.csv
# Frequency: 242
# track_90.csv
# Frequency: 99
# track_92.csv
# Frequency: 99
# track_93.csv
# Frequency: 100
# track_94.csv
# Frequency: 395
# track_95.csv
# Frequency: 206
# track_96.csv
# Frequency: 99
# track_97.csv
# Frequency: 833
# track_98.csv
# Frequency: 241
# track_99.csv
# Frequency: 247
# track_100.csv
# Frequency: 199
# track_101.csv
# Frequency: 75
# track_103.csv
# Frequency: 100
# track_104.csv
# Frequency: 99
# track_105.csv
# Frequency: 499
# track_106.csv
# Frequency: 410
# track_107.csv
# Frequency: 100
# track_108.csv
# Frequency: 99
# track_109.csv
# Frequency: 499
# track_110.csv
# Frequency: 100
# track_111.csv
# Frequency: 834
# track_112.csv
# Frequency: 500
# track_114.csv
# Frequency: 499
# track_115.csv
# Frequency: 834
# track_116.csv
# Frequency: 500
# track_117.csv
# Frequency: 845
# track_118.csv
# Frequency: 99
# track_119.csv
# Frequency: 241
# track_120.csv
# Frequency: 201
# track_121.csv
# Frequency: 99
# track_122.csv
# Frequency: 100
# track_123.csv
# Frequency: 99
# track_124.csv
# Frequency: 409
# track_125.csv
# Frequency: 834
# track_126.csv
# Frequency: 8895
# track_127.csv
# Frequency: 77
# track_128.csv
# Frequency: 100
# track_129.csv
# Frequency: 500
# track_130.csv
# Frequency: 189
# track_131.csv
# Frequency: 91
# track_132.csv
# Frequency: 247
# track_133.csv
# track_134.csv
# Frequency: 99
# track_135.csv
# Frequency: 100
# track_137.csv
# Frequency: 206
# track_138.csv
# Frequency: 405
# track_139.csv
# Frequency: 99
# track_140.csv
# Frequency: 251
# track_141.csv
# Frequency: 499
# track_142.csv
# Frequency: 100
# track_143.csv
# Frequency: 99
# track_144.csv
# Frequency: 100
# track_145.csv
# Frequency: 199
# track_146.csv
# Frequency: 841
# track_147.csv
# Frequency: 99
# track_148.csv
# Frequency: 408
# track_149.csv
# Frequency: 251
# track_150.csv
# Frequency: 100
# track_151.csv
# Frequency: 499
# track_152.csv
# Frequency: 409
# track_153.csv
# Frequency: 251
# track_154.csv
# Frequency: 405
# track_155.csv
# Frequency: 499
# track_156.csv
# Frequency: 499
# track_157.csv
# Frequency: 845
# track_158.csv
# Frequency: 99
# track_159.csv
# Frequency: 399
# track_160.csv
# Frequency: 99
# track_161.csv
# Frequency: 99
# track_162.csv
# Frequency: 194
# track_163.csv
# Frequency: 100
# track_164.csv
# Frequency: 199
# track_165.csv
# Frequency: 201
# track_166.csv
# Frequency: 499
# track_167.csv
# track_168.csv
# Frequency: 839
# track_169.csv
# Frequency: 93
# track_170.csv
# Frequency: 255
# track_171.csv
# Frequency: 248
# track_172.csv
# Frequency: 100
# track_173.csv
# Frequency: 100
# track_174.csv
# Frequency: 407
# track_175.csv
# Frequency: 405
# track_176.csv
# Frequency: 16626
# track_177.csv
# Frequency: 201
# track_178.csv
# Frequency: 99
# track_179.csv
# Frequency: 99
# track_180.csv
# Frequency: 100
# track_181.csv
# Frequency: 406
# track_182.csv
# Frequency: 100

# %%
X_df.shape
# Out:
# (751, 7)

# %%
X_df.dropna(inplace=True)

# %%
X_df.shape
# Out:
# (645, 7)

# %%
X_df['true_ans'] = X_df['true_ans'].astype(int)

# %%
X_df.head()
# Out:
#    index  amplitude   freq    freq_1  freq_1_amp    freq_2  freq_2_amp  \
# 0      0   8.700749  499.0  3.952816    0.404179  2.620889    0.286208
# 1      1   8.515114  499.0  3.952863    0.409035  2.622196    0.290147
# 2      2   8.636395  499.0  3.939474    0.443656  2.626316    0.306911
# 3      3   7.978906  499.0  3.945190    0.485288  2.615350    0.280812
# 4      4   1.935292  499.0  0.955434    0.102151  0.988380    0.093211
#
#    true_ans
# 0         2
# 1         2
# 2         2
# 3         2
# 4         3

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, GridSearchCV

# %%
X_df['true_ans'].value_counts()
# Out:
# 0    168
# 1    166
# 2    110
# 4    107
# 3     44
# 5     22
# 7     13
# 6     12
# 8      3
# Name: true_ans, dtype: int64

# %%
X_df.reset_index(inplace=True)

# %%
import random

ind_0 = random.sample(X_df[X_df.true_ans == 0].index.tolist(), 44)
ind_1 = random.sample(X_df[X_df.true_ans == 1].index.tolist(), 44)
ind_2 = random.sample(X_df[X_df.true_ans == 2].index.tolist(), 44)
ind_3 = random.sample(X_df[X_df.true_ans == 3].index.tolist(), 44)
ind_4 = random.sample(X_df[X_df.true_ans == 4].index.tolist(), 44)
ind_5 = random.sample(X_df[X_df.true_ans == 5].index.tolist(), 12)
ind_6 = random.sample(X_df[X_df.true_ans == 6].index.tolist(), 12)
ind_7 = random.sample(X_df[X_df.true_ans == 7].index.tolist(), 12)
ind_8 = random.sample(X_df[X_df.true_ans == 8].index.tolist(), 3)

ind_balanced = ind_0 + ind_1 + ind_2 + ind_3 + ind_4 + ind_5 + ind_6 + ind_7 + ind_8
len(ind_balanced), len(X_df)
# Out:
# (259, 645)

# %%
X_df_balanced = X_df.iloc[ind_balanced]

# %% [markdown]
# Training

# %%
X = X_df_balanced[['amplitude', 'freq_1', 'freq_2', 'freq_1_amp', 'freq_2_amp']]
y = X_df_balanced['true_ans']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

'''
tree = DecisionTreeClassifier(criterion='entropy', random_state=0)
params = {'max_depth': range(2, 20)}
clf = GridSearchCV(tree, params, cv=5)
best_model = clf.fit(X_train, y_train)

print(best_model.best_estimator_.get_params('max_depth'))
y_pred = best_model.predict(X_test)
accuracy_score(y_test, y_pred)
'''

clf = DecisionTreeClassifier(criterion='entropy', random_state=0, max_depth=8)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, random_state=0)

# %% [markdown]
# Testing

# %%
X_test_df.head()
# Out:
#    amplitude   freq    freq_1  freq_1_amp    freq_2  freq_2_amp  track_num
# 0   0.225790  207.0  2.821377    0.003561  2.771879    0.002932          0
# 1   1.037320  395.0  6.462029    0.009785  6.836146    0.008330          1
# 2   1.022796  250.0  1.666102    0.074564  1.637863    0.072924          2
# 3   0.222790  499.0  2.645287    0.000882  2.616218    0.000868          3
# 4   0.340241  395.0  6.077493    0.001908  6.485130    0.001796          4

# %%
X_test_df['track_num'] = X_test_df['track_num'].astype(int)

# %%
X_test_df.shape
# Out:
# (183, 7)

# %%
X_test_df.amplitude.isnull().sum(), X_test_df.freq_1.isnull().sum(), X_test_df.freq_2.isnull().sum(), X_test_df.freq_1_amp.isnull().sum(), X_test_df.freq_2_amp.isnull().sum()
# Out:
# (13, 13, 13, 14, 14)

# %%
X_test_df_copy = X_test_df.copy()

# %%
X_test_df['amplitude'].fillna(X_test_df['amplitude'].median(), inplace=True)

# %%
X_test_df['freq_1'].fillna(X_test_df['freq_1'].median(), inplace=True)

# %%
X_test_df['freq_2'].fillna(X_test_df['freq_2'].median(), inplace=True)

# %%
X_test_df['freq_1_amp'].fillna(X_test_df['freq_1_amp'].median(), inplace=True)

# %%
X_test_df['freq_2_amp'].fillna(X_test_df['freq_2_amp'].median(), inplace=True)

# %%
X_test_df.amplitude.isnull().sum(), X_test_df.freq_1.isnull().sum(), X_test_df.freq_2.isnull().sum()
# Out:
# (0, 0, 0)

# %%
X_test = X_test_df[['amplitude', 'freq_1', 'freq_2', 'freq_1_amp', 'freq_2_amp']]
y_pred = clf.predict(X_test)

# %%
y_pred.shape
# Out:
# (183,)

# %%
res = pd.DataFrame({'track_num' : X_test_df['track_num'], 'action' : y_pred})
res.head(10)
# Out:
#    track_num  action
# 0          0       7
# 1          1       5
# 2          2       4
# 3          3       0
# 4          4       0
# 5          5       7
# 6          6       8
# 7          7       6
# 8          8       0
# 9          9       7

# %%
res.to_csv('tests/submission_5.csv', index=False)
